# %%
import pandas as pd
import numpy as np
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import seaborn as sns

# %%
df=pd.read_csv('a1_RestaurantReviews_HistoricDump.tsv',sep='\t')
df.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
for i in range(len(df)):
    df['Review'][i]=re.sub('[^a-zA-z]',' ',df['Review'][i])
    df['Review'][i]=df['Review'][i].lower()
# Out:
# <ipython-input-3-a9be8d8d7bd7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review'][i]=re.sub('[^a-zA-z]',' ',df['Review'][i])
# <ipython-input-3-a9be8d8d7bd7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review'][i]=df['Review'][i].lower()

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['Review'] = df['Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
df['Review'] = df.apply(lambda row: nltk.word_tokenize(row['Review']), axis=1)

# %%
from gensim.parsing.porter import PorterStemmer
porter_stemmer = PorterStemmer()
# Get the stemmed_tokens
df['Review'] = [[porter_stemmer.stem(word) for word in tokens] for tokens in df['Review'] ]
df.head(10)
# Out:
#                                               Review  Liked
# 0                                 [wow, love, place]      1
# 1                                      [crust, good]      0
# 2                             [tasti, textur, nasti]      0
# 3  [stop, late, mai, bank, holidai, rick, steve, ...      1
# 4                       [select, menu, great, price]      1
# 5                      [get, angri, want, damn, pho]      0
# 6                            [honeslti, tast, fresh]      0
# 7  [potato, like, rubber, could, tell, made, ahea...      0
# 8                                       [fri, great]      1
# 9                                     [great, touch]      1

# %%
for i in range(len(df['Review'])):
    df['Review'][i] = ' '.join(df['Review'][i])
# Out:
# <ipython-input-7-6b78370b2d1f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review'][i] = ' '.join(df['Review'][i])

# %%
df['Review']
# Out:
# 0                                         wow love place
# 1                                             crust good
# 2                                     tasti textur nasti
# 3      stop late mai bank holidai rick steve recommen...
# 4                                select menu great price
#                              ...
# 895           want first sai server great perfect servic
# 896                                    pizza select good
# 897                                  strawberri tea good
# 898                highli unprofession rude loyal patron
# 899                                  overal great experi
# Name: Review, Length: 900, dtype: object

# %%
#Train a Word2Vec model using Gensim
import gensim
Min_count=1      #It will ignore all the words with a total frequency lower than this
Size = 200      #It tells the dimensionality of the word vectors
Workers=4        #These are the threads to train the model
Window=5         #Maximum distance between the current and predicted word within a sentence
#train word2vec model
model = gensim.models.Word2Vec(sentences = df['Review'],window=Window, workers = Workers, min_count = Min_count)
# #Vocabulary size
# words = list(model.wv.vocab)
# print('Here is the Vocabulary Size.. %d' % len(words))

# %%
model

# %%
words = list(model.wv.get_vector)
# print('Here is the Vocabulary Size.. %d' % len(words))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a252ef12c59c> in <module>
# ----> 1 words = list(model.wv.get_vector)
#       2 # print('Here is the Vocabulary Size.. %d' % len(words))
#
# TypeError: 'method' object is not iterable

# %%
# rock_idx = model.wv.vocab["rock"].index  # 🚫
# rock_cnt = model.wv.vocab["rock"].count  # 🚫
# vocab_len = len(model.wv.vocab)  # 🚫

# rock_idx = model.wv.key_to_index["rock"]
# rock_cnt = model.wv.get_vecattr("rock", "count")  # 👍
vocab_len = len(model.wv)  # 👍

# %%
vocab_len
# Out:
# 27

# %%
import bokeh.plotting as bp
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.plotting import figure, show, output_notebook
import matplotlib.pyplot as plt

voc_size=3000
#Defining the chart
output_notebook()
plot_chart = bp.figure(plot_width=700, plot_height=600, title="A map/plot of 3000 word vectors",
    tools="pan,wheel_zoom,box_zoom,reset,hover",
    x_axis_type=None, y_axis_type=None, min_border=1)

#Extracting the list of word vectors, limiting to 1000, each is of 200 dimensions
word_vectors = [model[w] for w in list(model.wv.get_index())[:voc_size]]

# Reducing dimensionality by converting the vectors to 2d vectors
from sklearn.manifold import TSNE
tsne_model = TSNE(n_components=2, verbose=1, random_state=0)
tsne_w2v = tsne_model.fit_transform(word_vectors)

# Storing data in a dataframe
tsne_df = pd.DataFrame(tsne_w2v, columns=['x', 'y'])
tsne_df['words'] = list(model.wv.vocab.keys())[:voc_size]

# Corresponding word appears when you hover on the data point.
plot_chart.scatter(x='x', y='y', source=tsne_df)
hover = plot_chart.select(dict(type=HoverTool))
hover.tooltips={"word": "@words"}
show(plot_chart)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1122">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-524573d6602a> in <module>
#      12
#      13 #Extracting the list of word vectors, limiting to 1000, each is of 200 dimensions
# ---> 14 word_vectors = [model[w] for w in list(model.wv.get_index())[:voc_size]]
#      15
#      16 # Reducing dimensionality by converting the vectors to 2d vectors
#
# TypeError: get_index() missing 1 required positional argument: 'key'

# %%
import numpy as np 
#Build word vector set by using the average value of all word vectors , then scale
def buildWordVector(text, size):
    vec = np.zeros(size).reshape((1, size)) #As word vectors are of zero length size value(i.e 300) 
    count = 0 # no. of words with a valid vector in the sentence/review
    for word in text: #for each word in a sentence/review
        try:
            vec += model[word].reshape((1, size))
            count += 1.
        except KeyError:
            continue
    if count != 0:
        vec /= count
    return vec

# %%
from sklearn.preprocessing import scale
vecs = np.concatenate([buildWordVector(z, Size) for z in df['Review']])
#print("Before Scaling:",vecs[1:2])
vecs = scale(vecs)
#print("After Scaling:",vecs[1:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-597003dcb78c> in <module>
#       1 from sklearn.preprocessing import scale
# ----> 2 vecs = np.concatenate([buildWordVector(z, Size) for z in df['Review']])
#       3 #print("Before Scaling:",vecs[1:2])
#       4 vecs = scale(vecs)
#       5 #print("After Scaling:",vecs[1:2])
#
# <ipython-input-15-597003dcb78c> in <listcomp>(.0)
#       1 from sklearn.preprocessing import scale
# ----> 2 vecs = np.concatenate([buildWordVector(z, Size) for z in df['Review']])
#       3 #print("Before Scaling:",vecs[1:2])
#       4 vecs = scale(vecs)
#       5 #print("After Scaling:",vecs[1:2])
#
# <ipython-input-13-984032a89a54> in buildWordVector(text, size)
#       6     for word in text: #for each word in a sentence/review
#       7         try:
# ----> 8             vec += model[word].reshape((1, size))
#       9             count += 1.
#      10         except KeyError:
#
# TypeError: 'Word2Vec' object is not subscriptable
